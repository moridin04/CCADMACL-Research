# %% [markdown]
# <a href="https://colab.research.google.com/github/moridin04/CCADMACL-Research/blob/main/PCA_CCFD_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Principal Component Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.decomposition import PCA

# %% [markdown]
# ## Step 1: Load the dataset

# %%
cfd = pd.read_csv('creditcard.csv')

X = cfd.drop('Class', axis=1)
y = cfd['Class']

feature_names = X.columns

# %% [markdown]
# This dataset is made of 30 features/dimensions: Time, V1-V28, Amount

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# 0       0.462388  0.239599  0.098698  0.363787  ...  0.251412 -0.018307
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.524980  0.247998
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300
# 4       0.095921  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  1.475829  0.213454
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.059616  0.214205
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.001396  0.232045
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.127434  0.265245
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#         Amount
# 0       149.62
# 1         2.69
# 2       378.66
# 3       123.50
# 4        69.99
# ...        ...
# 284802    0.77
# 284803   24.79
# 284804   67.88
# 284805   10.00
# 284806  217.00
#
# [284807 rows x 30 columns]

# %%
print("Missing values in each column:")
print(X.isnull().sum())
# Out:
# Missing values in each column:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %% [markdown]
# ## Step 2: Use PCA to for reduce the dimensions

# %%
X.shape
# Out:
# (284807, 30)

# %% [markdown]
# This shows that we have 284,807 transactions and 30 features (Time, V1, V2, ... V28, Amount)

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=25)
X_principal = pca.fit_transform(X_scaled)

# %% [markdown]
# Here, we implemented StandardScaler to ensure optimal performance.
#
# StandardScaler ensures that each feature has equal contribution to PCA implementation.
#
# Then, we selected 10 principal components out of 30 features.

# %% [markdown]
# Dimensions of Credit Card Fraud Detection dataset after PCA

# %%
print("Shape of the transformed data after PCA:", X_principal.shape)
# Out:
# Shape of the transformed data after PCA: (284807, 25)

# %% [markdown]
# ## Step 3: Display the explained variances of each principal component using a Scree Plot

# %%
explained_variance = pca.explained_variance_ratio_

PC1_explainedvariance = explained_variance[0]
print("Explained variance of PC1", PC1_explainedvariance)

PC2_explainedvariance = explained_variance[1]
print("Explained variance of PC2", PC2_explainedvariance)

PC3_explainedvariance = explained_variance[2]
print("Explained variance of PC3", PC3_explainedvariance)

PC4_explainedvariance = explained_variance[3]
print("Explained variance of PC4", PC4_explainedvariance)

PC5_explainedvariance = explained_variance[4]
print("Explained variance of PC5", PC5_explainedvariance)

PC6_explainedvariance = explained_variance[5]
print("Explained variance of PC6", PC6_explainedvariance)

PC7_explainedvariance = explained_variance[6]
print("Explained variance of PC7", PC7_explainedvariance)

PC8_explainedvariance = explained_variance[7]
print("Explained variance of PC8", PC8_explainedvariance)

PC9_explainedvariance = explained_variance[8]
print("Explained variance of PC9", PC9_explainedvariance)

PC10_explainedvariance = explained_variance[9]
print("Explained variance of PC10", PC10_explainedvariance)

PC11_explainedvariance = explained_variance[10]
print("Explained variance of PC11", PC11_explainedvariance)

PC12_explainedvariance = explained_variance[11]
print("Explained variance of PC12", PC12_explainedvariance)

PC13_explainedvariance = explained_variance[12]
print("Explained variance of PC13", PC13_explainedvariance)

PC14_explainedvariance = explained_variance[13]
print("Explained variance of PC14", PC14_explainedvariance)

PC15_explainedvariance = explained_variance[14]
print("Explained variance of PC15", PC15_explainedvariance)

PC16_explainedvariance = explained_variance[15]
print("Explained variance of PC16", PC16_explainedvariance)

PC17_explainedvariance = explained_variance[16]
print("Explained variance of PC17", PC17_explainedvariance)

PC18_explainedvariance = explained_variance[17]
print("Explained variance of PC18", PC18_explainedvariance)

PC19_explainedvariance = explained_variance[18]
print("Explained variance of PC19", PC19_explainedvariance)

PC20_explainedvariance = explained_variance[19]
print("Explained variance of PC20", PC20_explainedvariance)

PC21_explainedvariance = explained_variance[20]
print("Explained variance of PC21", PC21_explainedvariance)

PC22_explainedvariance = explained_variance[21]
print("Explained variance of PC22", PC22_explainedvariance)

PC23_explainedvariance = explained_variance[22]
print("Explained variance of PC23", PC23_explainedvariance)

PC24_explainedvariance = explained_variance[23]
print("Explained variance of PC24", PC24_explainedvariance)

PC25_explainedvariance = explained_variance[24]
print("Explained variance of PC25", PC25_explainedvariance)
# Out:
# Explained variance of PC1 0.06527521274102722
# Explained variance of PC2 0.05612313303362721
# Explained variance of PC3 0.033333333333334055
# Explained variance of PC4 0.033333333333333624
# Explained variance of PC5 0.03333333333333351
# Explained variance of PC6 0.033333333333333486
# Explained variance of PC7 0.033333333333333465
# Explained variance of PC8 0.03333333333333342
# Explained variance of PC9 0.033333333333333416
# Explained variance of PC10 0.0333333333333334
# Explained variance of PC11 0.03333333333333338
# Explained variance of PC12 0.03333333333333337
# Explained variance of PC13 0.03333333333333335
# Explained variance of PC14 0.03333333333333334
# Explained variance of PC15 0.03333333333333334
# Explained variance of PC16 0.03333333333333331
# Explained variance of PC17 0.0333333333333333
# Explained variance of PC18 0.03333333333333329
# Explained variance of PC19 0.03333333333333328
# Explained variance of PC20 0.033333333333333263
# Explained variance of PC21 0.03333333333333325
# Explained variance of PC22 0.033333333333333236
# Explained variance of PC23 0.033333333333333236
# Explained variance of PC24 0.03333333333333322
# Explained variance of PC25 0.03333333333333317

# %%
plt.figure(figsize=(10, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.7, align='center', color='violet')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Individual Explained Variance')

plt.show()

# %% [markdown]
# Here, we see PC1 and PC2 having high variance, which means it captured much information.

# %%
explained_variance = pca.explained_variance_ratio_ * 100
for i, var in enumerate(explained_variance):
    print(f"PC{i+1}: {var:.2f}% variance explained")
# Out:
# PC1: 6.53% variance explained
# PC2: 5.61% variance explained
# PC3: 3.33% variance explained
# PC4: 3.33% variance explained
# PC5: 3.33% variance explained
# PC6: 3.33% variance explained
# PC7: 3.33% variance explained
# PC8: 3.33% variance explained
# PC9: 3.33% variance explained
# PC10: 3.33% variance explained
# PC11: 3.33% variance explained
# PC12: 3.33% variance explained
# PC13: 3.33% variance explained
# PC14: 3.33% variance explained
# PC15: 3.33% variance explained
# PC16: 3.33% variance explained
# PC17: 3.33% variance explained
# PC18: 3.33% variance explained
# PC19: 3.33% variance explained
# PC20: 3.33% variance explained
# PC21: 3.33% variance explained
# PC22: 3.33% variance explained
# PC23: 3.33% variance explained
# PC24: 3.33% variance explained
# PC25: 3.33% variance explained

# %% [markdown]
# 81%

# %% [markdown]
# ## Step 4: Plot the features after doing PCA

# %%
PC_df = pd.DataFrame({'PC1': X_principal[:, 0], 'PC2': X_principal[:, 1], 'PC3': X_principal[:, 2],
                      'PC4': X_principal[:, 3], 'PC5': X_principal[:, 4], 'PC6': X_principal[:, 5],
                      'PC7': X_principal[:, 6], 'PC8': X_principal[:, 7], 'PC9': X_principal[:, 8],
                      'PC10': X_principal[:, 9], 'PC11': X_principal[:, 10], 'PC12': X_principal[:, 11],
                      'PC13': X_principal[:, 12], 'PC14': X_principal[:, 13], 'PC15': X_principal[:, 14],
                      'PC16': X_principal[:, 15], 'PC17': X_principal[:, 16], 'PC18': X_principal[:, 17],
                      'PC19': X_principal[:, 18], 'PC20': X_principal[:, 19], 'PC21': X_principal[:, 20],
                      'PC22': X_principal[:, 21], 'PC23': X_principal[:, 22], 'PC24': X_principal[:, 23],
                      'PC25': X_principal[:, 24],
                      })
PC_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.416630 -2.532664  0.610384  0.333856  0.389871 -0.185773  0.789836
# 1 -0.393453 -2.077326  0.600515  0.073773 -0.418495 -0.215120  0.656130
# 2  1.868525 -2.533497 -0.055197  1.257310  1.363593 -1.925472  2.081274
# 3  0.315744 -1.783506 -0.207880  2.792977 -0.519036 -0.547818 -0.210795
# 4 -0.004379 -1.488415 -0.487332  0.070169  0.405306  0.278263 -0.321165
#
#         PC8       PC9      PC10  ...      PC16      PC17      PC18      PC19  \
# 0  0.835010 -0.807475  0.508153  ...  0.129631  0.111725  0.664649  0.373714
# 1 -0.793803  0.382103 -0.327869  ...  0.339797 -0.585040 -0.565534  0.294010
# 2 -0.695225 -0.058073 -0.967450  ... -0.095520  0.860614 -0.201113 -0.434359
# 3  0.708673 -0.831208 -1.176140  ...  0.361073  1.034206 -0.498975 -1.119764
# 4  0.823956 -0.833559 -0.265499  ... -0.396949  0.334614  0.152617  0.773138
#
#        PC20      PC21      PC22      PC23      PC24      PC25
# 0 -0.168285 -0.681509 -0.190543 -0.458513  0.848852 -0.498340
# 1  0.167611  0.131250 -0.197897  0.573701 -0.734225  0.064017
# 2 -0.101759 -0.641602 -1.043830  0.441428  3.022950 -0.959044
# 3 -0.516463  0.050235 -0.671332  0.836756  0.538511  1.033164
# 4 -0.389244 -0.650900  1.324871 -0.290448  0.557641 -1.157626
#
# [5 rows x 25 columns]

# %%
PC_df
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0       0.416630 -2.532664  0.610384  0.333856  0.389871 -0.185773  0.789836
# 1      -0.393453 -2.077326  0.600515  0.073773 -0.418495 -0.215120  0.656130
# 2       1.868525 -2.533497 -0.055197  1.257310  1.363593 -1.925472  2.081274
# 3       0.315744 -1.783506 -0.207880  2.792977 -0.519036 -0.547818 -0.210795
# 4      -0.004379 -1.488415 -0.487332  0.070169  0.405306  0.278263 -0.321165
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -1.493200  1.900149  1.856804 -1.297853  0.578455  1.187040 -2.674646
# 284803 -0.366836  0.842366 -0.224483 -0.092465  0.686837 -2.152422  1.601817
# 284804 -0.194063  2.070788 -0.041067  0.307832  0.594699  0.006989  1.139557
# 284805 -0.466089  1.225394  0.023545  0.075627  0.678808  0.860872  0.452327
# 284806  0.767597  1.905903 -0.165599  0.513606  0.442324 -1.252062 -0.007720
#
#              PC8       PC9      PC10  ...      PC16      PC17      PC18  \
# 0       0.835010 -0.807475  0.508153  ...  0.129631  0.111725  0.664649
# 1      -0.793803  0.382103 -0.327869  ...  0.339797 -0.585040 -0.565534
# 2      -0.695225 -0.058073 -0.967450  ... -0.095520  0.860614 -0.201113
# 3       0.708673 -0.831208 -1.176140  ...  0.361073  1.034206 -0.498975
# 4       0.823956 -0.833559 -0.265499  ... -0.396949  0.334614  0.152617
# ...          ...       ...       ...  ...       ...       ...       ...
# 284802 -0.288939 -2.474239  2.119193  ... -6.907766  3.820199  5.091750
# 284803  0.810996 -0.457186 -0.008930  ... -0.012771  0.623526 -0.705063
# 284804 -1.633303  1.356697 -0.448978  ...  1.186191  0.647162  1.875180
# 284805  0.888700 -1.871939 -0.105564  ...  0.013520 -0.394301  0.647348
# 284806  0.734239 -0.584684  0.514856  ... -0.619444  0.172257 -0.364114
#
#             PC19      PC20      PC21      PC22      PC23      PC24      PC25
# 0       0.373714 -0.168285 -0.681509 -0.190543 -0.458513  0.848852 -0.498340
# 1       0.294010  0.167611  0.131250 -0.197897  0.573701 -0.734225  0.064017
# 2      -0.434359 -0.101759 -0.641602 -1.043830  0.441428  3.022950 -0.959044
# 3      -1.119764 -0.516463  0.050235 -0.671332  0.836756  0.538511  1.033164
# 4       0.773138 -0.389244 -0.650900  1.324871 -0.290448  0.557641 -1.157626
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -0.453779  4.782734  5.428293  4.197644  4.179683 -1.289003  4.339672
# 284803 -1.103729  0.097060 -1.069109  0.164777 -0.454796  1.305803 -0.836259
# 284804 -0.087797  0.398179  0.305639 -0.432023 -0.725801  0.507942 -0.389468
# 284805  2.102284  1.073091 -0.291812  0.345751 -1.552358  0.110841 -0.680612
# 284806 -0.378965  0.204288 -1.013230 -0.591959 -0.171743  1.227191  0.125229
#
# [284807 rows x 25 columns]

# %%
cumulative_explained_variance = np.cumsum(explained_variance)
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--', color='blue')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
PC_df.shape
# Out:
# (284807, 25)

# %% [markdown]
# This table shows the dataset after PCA was implemented. Each row represents all 284,806 transactions. Each column represents all 30 features turned into 10 principal components.
#
# Each value is the weighted sum of the original 30 feature values, transformed into the new PCA space. The higher the value, the higher the contribution to PCA.
#
# We can see how much each feature contribute when we implement loadings.

# %%
plt.figure(figsize=(8,5))
plt.scatter(PC_df['PC1'], PC_df['PC2'])
plt.title('PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(PC_df['PC3'], PC_df['PC4'])
plt.title('PCA')
plt.xlabel('PC3')
plt.ylabel('PC4')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(PC_df['PC5'], PC_df['PC6'])
plt.title('PCA')
plt.xlabel('PC5')
plt.ylabel('PC6')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(PC_df['PC7'], PC_df['PC8'])
plt.title('PCA')
plt.xlabel('PC7')
plt.ylabel('PC8')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(PC_df['PC9'], PC_df['PC10'])
plt.title('PCA')
plt.xlabel('PC9')
plt.ylabel('PC10')
plt.show()

# %% [markdown]
# ## Step 5: Get the loadings

# %% [markdown]
# Each feature will get a weight or loading that indicate the how much it contributes to a specific principal component (PC)

# %%
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

loading_matrix = pd.DataFrame(loadings, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12',
                                                 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19', 'PC20', 'PC21', 'PC22', 'PC23', 'PC24', 'PC25'], index=feature_names)
loading_matrix
# Out:
#              PC1       PC2           PC3           PC4           PC5  \
# Time   -0.041487  0.916694 -6.681975e-15 -7.439344e-16 -1.298341e-15
# V1     -0.240066  0.146563 -2.852111e-02 -2.768394e-02 -6.064518e-02
# V2     -0.547927 -0.039505 -9.694436e-03  9.660790e-02  5.253337e-02
# V3     -0.199450 -0.572663  1.330933e-01  4.174496e-02 -7.062988e-03
# V4      0.106443 -0.136432  3.784144e-02  5.495074e-02  5.968516e-02
# V5     -0.406192  0.213659 -4.033350e-02 -2.931845e-02 -8.504167e-02
# V6      0.225609 -0.074209  4.239558e-02  7.499975e-03 -3.348581e-02
# V7      0.406337  0.132502 -2.126859e-03 -2.066383e-02 -9.798615e-02
# V8     -0.104772 -0.054449  1.865773e-02  3.003415e-02 -7.626203e-03
# V9     -0.045284 -0.013718 -7.729405e-02 -4.887201e-02 -3.295141e-02
# V10    -0.106070  0.036218  2.830763e-02 -3.184728e-02  1.225691e-01
# V11     0.010831 -0.332096  4.441531e-02  1.141294e-02  8.123061e-02
# V12    -0.015230  0.166271  6.916360e-01  1.422570e-02  1.481812e-03
# V13     0.008316 -0.088109 -6.826620e-01 -3.676524e-02  1.590591e-02
# V14     0.039105 -0.130806 -2.296556e-03 -8.077032e-02  9.184629e-03
# V15     0.004861 -0.246116  5.848833e-02  1.636606e-01  1.853358e-01
# V16    -0.004550  0.015773  1.283288e-02 -3.310234e-01 -8.309130e-02
# V17     0.010716 -0.097929  2.850270e-02 -5.489136e-01 -1.248336e-01
# V18     0.032874  0.122956 -6.497083e-02  6.483332e-01 -9.137802e-02
# V19    -0.059199  0.036177  1.127653e-02 -2.800942e-01 -1.035729e-02
# V20     0.352449 -0.052041  2.040250e-02  1.665731e-02  1.232057e-02
# V21     0.107448  0.065028 -9.609536e-03 -9.716648e-02  7.301951e-01
# V22    -0.073108  0.190068 -5.014858e-02 -8.062431e-02  4.506172e-01
# V23    -0.118445  0.063209  1.545384e-02 -1.042282e-01  4.788889e-02
# V24     0.006011 -0.021452  5.103900e-02  2.030107e-02  1.266490e-01
    columns=[f'PC{i+1}' for i in range(pca.n_components_)],
    index=feature_names
)
print(loadings['PC1'].sort_values(ascending=False).head(5))
# Out:
# Amount    0.988870
# V7        0.406337
# V20       0.352449
# V6        0.225609
# V21       0.107448
# Name: PC1, dtype: float64

# %% [markdown]
# Here, we can see that the Amount feature contributes 0.988870 to PC1.

# %%
loadings = pd.DataFrame(
    pca.components_.T * np.sqrt(pca.explained_variance_),
    columns=[f'PC{i+1}' for i in range(pca.n_components_)],
    index=feature_names
)
print(loadings['PC2'].sort_values(ascending=False).head(5))
# Out:
# Time    0.916694
# V5      0.213659
# V22     0.190068
# V12     0.166271
# V1      0.146563
# Name: PC2, dtype: float64

# %% [markdown]
# Here, we can see that the Time feature contributes 0.916694 to PC2.

# %%
for i in range(pca.n_components_):
    print(f"Top features for PC{i+1}:")
    print(loadings[f'PC{i+1}'].sort_values(ascending=False).head(5))
    print()
# Out:
# Top features for PC1:
# Amount    0.988870
# V7        0.406337
# V20       0.352449
# V6        0.225609
# V21       0.107448
# Name: PC1, dtype: float64
#
# Top features for PC2:
# Time    0.916694
# V5      0.213659
# V22     0.190068
# V12     0.166271
# V1      0.146563
# Name: PC2, dtype: float64
#
# Top features for PC3:
# V12    0.691636
# V3     0.133093
# V25    0.086103
# V15    0.058488
# V24    0.051039
# Name: PC3, dtype: float64
#
# Top features for PC4:
# V18    0.648333
# V15    0.163661
# V2     0.096608
# V4     0.054951
# V3     0.041745
# Name: PC4, dtype: float64
#
# Top features for PC5:
# V21    0.730195
# V22    0.450617
# V15    0.185336
# V24    0.126649
# V10    0.122569
# Name: PC5, dtype: float64
#
# Top features for PC6:
# V25    0.531567
# V26    0.434231
# V19    0.311257
# V24    0.180670
# V20    0.053899
# Name: PC6, dtype: float64
#
# Top features for PC7:
# V15    0.688784
# V16    0.187773
# V5     0.138681
# V10    0.123261
# V17    0.060221
# Name: PC7, dtype: float64
#
# Top features for PC8:
# V27    0.430923
# V3     0.237893
# V19    0.187828
# V4     0.184843
# V22    0.166891
# Name: PC8, dtype: float64
#
# Top features for PC9:
# V11    0.625487
# V24    0.479286
# V27    0.208516
# V5     0.120713
# V17    0.104443
# Name: PC9, dtype: float64
#
# Top features for PC10:
# V9     0.480858
# V4     0.223941
# V17    0.129906
# V8     0.107141
# V14    0.107085
# Name: PC10, dtype: float64
#
# Top features for PC11:
# V6     0.543434
# V5     0.235162
# V19    0.128089
# V11    0.105912
# V25    0.099149
# Name: PC11, dtype: float64
#
# Top features for PC12:
# V10    0.433154
# V7     0.344377
# V24    0.282704
# V3     0.247428
# V2     0.114223
# Name: PC12, dtype: float64
#
# Top features for PC13:
# V16    0.428128
# V19    0.280330
# V9     0.268726
# V20    0.266917
# V24    0.240805
# Name: PC13, dtype: float64
#
# Top features for PC14:
# V8     0.428492
# V7     0.339785
# V21    0.310069
# V9     0.283720
# V26    0.248068
# Name: PC14, dtype: float64
#
# Top features for PC15:
# V2     0.457129
# V4     0.367277
# V6     0.291062
# V16    0.239572
# V1     0.185929
# Name: PC15, dtype: float64
#
# Top features for PC16:
# V1     0.643063
# V27    0.248261
# V25    0.246075
# V21    0.165291
# V4     0.142741
# Name: PC16, dtype: float64
#
# Top features for PC17:
# V22    0.457865
# V27    0.317951
# V25    0.296491
# V7     0.222364
# V14    0.221185
# Name: PC17, dtype: float64
#
# Top features for PC18:
# V6     0.412133
# V10    0.331762
# V24    0.313766
# V5     0.256658
# V27    0.245509
# Name: PC18, dtype: float64
#
# Top features for PC19:
# V19    0.408849
# V14    0.317887
# V7     0.309408
# V1     0.295479
# V10    0.265287
# Name: PC19, dtype: float64
#
# Top features for PC20:
# V27    0.352903
# V2     0.301917
# V15    0.301463
# V14    0.218585
# V21    0.194821
# Name: PC20, dtype: float64
#
# Top features for PC21:
# V8     0.660699
# V10    0.386231
# V1     0.217021
# V24    0.129547
# V28    0.121357
# Name: PC21, dtype: float64
#
# Top features for PC22:
# V9     0.425500
# V26    0.377520
# V10    0.291224
# V16    0.225432
# V20    0.161227
# Name: PC22, dtype: float64
#
# Top features for PC23:
# V20    0.448620
# V11    0.280535
# V10    0.276078
# V25    0.255157
# V27    0.249187
# Name: PC23, dtype: float64
#
# Top features for PC24:
# V23    0.478595
# V17    0.222039
# V9     0.195375
# V7     0.193702
# V6     0.184303
# Name: PC24, dtype: float64
#
# Top features for PC25:
# V16    0.329705
# V25    0.324127
# V18    0.314103
# V22    0.262655
# V14    0.235570
# Name: PC25, dtype: float64

# %% [markdown]
# ## Step 6: Use a clustering algorithm

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300,
                  n_init = 10, random_state = 0)
kmeans.fit(PC_df)
labels = kmeans.labels_  # Cluster labels for each point
centroids = kmeans.cluster_centers_  # Cluster centroids

# %%
plt.figure(figsize=(8, 6))
for i in range(2):
    cluster_points = X_principal[labels == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1],
                label=f'Cluster {i + 1}')

# Plot centroids
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title('K-means Clustering')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Here, we see two clusters formed by PC1 and PC2 through K-Means Clustering Algorithm.
#
# We assume Cluster 1 to depict fraudulent transactions.
#
# We assume Cluster 2 to depict normal transactions, as normal transactions mostly compose the entire dataset.

# %% [markdown]
# ## Step 7: Outlier Detection using PCA

# %%
# Calculate the distance of each point from the centroid of its cluster
distances = np.sqrt(((X_principal - centroids[labels])**2).sum(axis=1))

outlier_threshold = np.percentile(distances, 95)
outliers = distances > outlier_threshold

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_principal[:, 0], X_principal[:, 1], c=outliers, cmap='coolwarm', alpha=0.6, label='Data Points')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='black', marker='X', label='Centroids')
plt.title('Outlier Detection using PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Count the number of outliers
print(f"Number of outliers detected: {outliers.sum()}")
# Out:
# Number of outliers detected: 14241

# %%
# Analyze outlier class distribution
outlier_indices = np.where(outliers)[0]
outlier_classes = y.iloc[outlier_indices].value_counts()
print("Outlier class distribution:")
print(outlier_classes)
# Out:
# Outlier class distribution:
# Class
# 0    13813
# 1      428
# Name: count, dtype: int64
